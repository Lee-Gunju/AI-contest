# %% [markdown]
# <a href="https://colab.research.google.com/github/Lee-Gunju/Lee-Gunju/blob/master/BIGDATA_lecture_Midterm_Project_Submission_leegeonju_2020120215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

reviews = pd.read_csv("/content/dedupe_challenge.csv")

# %%
reviews.shape
# Out:
# (129980, 13)

# %%
reviews.head()
# Out:
#     country  ...               winery
# 0     Italy  ...              Nicosia
# 1  Portugal  ...  Quinta dos Avidagos
# 2        US  ...            Rainstorm
# 3        US  ...           St. Julian
# 4        US  ...         Sweet Cheeks
#
# [5 rows x 13 columns]

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129975  Anna Lee C. Iijima                   NaN      90
# 129976        Paul Gregutt           @paulgwine       90
# 129977          Roger Voss            @vossroger      90
# 129978          Roger Voss            @vossroger      90
# 129979          Roger Voss            @vossroger      90
#
# [129980 rows x 3 columns]

# %%
reviews.set_index("title")
# Out:
#                                                      country  ...                                    winery
# title                                                         ...
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy  ...                                   Nicosia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal  ...                       Quinta dos Avidagos
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US  ...                                 Rainstorm
# St. Julian 2013 Reserve Late Harvest Riesling (...        US  ...                                St. Julian
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US  ...                              Sweet Cheeks
# ...                                                      ...  ...                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany  ...  Dr. H. Thanisch (Erben Müller-Burggraef)
# ...

# %%
reviews.points.describe()
# Out:
# count    129980.000000
# mean         88.446946
# std           3.039721
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
reviews.describe()
# Out:
#               points          price
# count  129980.000000  120984.000000
# mean       88.446946      35.361783
# std         3.039721      41.021130
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9535
# 86     12602
# 87     16935
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
country_groupby = reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
country_groupby
# Out:
#                               country  ...                winery
# country   province                     ...
# Argentina Mendoza Province  Argentina  ...  Bodega Catena Zapata
#           Other             Argentina  ...                Colomé
# Armenia   Armenia             Armenia  ...              Van Ardi
# Australia Australia Other   Australia  ...       Marquis Philips
#           New South Wales   Australia  ...            De Bortoli
# ...                               ...  ...                   ...
# Uruguay   Juanico             Uruguay  ...        Familia Deicas
#           Montevideo          Uruguay  ...                 Bouza
#           Progreso            Uruguay  ...                Pisano
#           San Jose            Uruguay  ...        Castillo Viejo
#           Uruguay             Uruguay  ...               Narbona
#
# [425 rows x 13 columns]

# %%
country_groupby
# Out:
#                               country  ...                winery
# country   province                     ...
# Argentina Mendoza Province  Argentina  ...  Bodega Catena Zapata
#           Other             Argentina  ...                Colomé
# Armenia   Armenia             Armenia  ...              Van Ardi
# Australia Australia Other   Australia  ...       Marquis Philips
#           New South Wales   Australia  ...            De Bortoli
# ...                               ...  ...                   ...
# Uruguay   Juanico             Uruguay  ...        Familia Deicas
#           Montevideo          Uruguay  ...                 Bouza
#           Progreso            Uruguay  ...                Pisano
#           San Jose            Uruguay  ...        Castillo Viejo
#           Uruguay             Uruguay  ...               Narbona
#
# [425 rows x 13 columns]

# %%
price_agg = reviews.groupby(['country']).price.agg([len, min, max])
price_agg
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4476.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2166.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# Australia Australia Other    245
#           New South Wales     85
# ...                          ...
# Uruguay   Juanico             12
#           Montevideo          11
#           Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#           country               province    len
# 179        Greece  Muscat of Kefallonian      1
# 192        Greece          Sterea Ellada      1
# 194        Greece                 Thraki      1
# 354  South Africa             Paardeberg      1
# 40         Brazil       Serra do Sudeste      1
# ..            ...                    ...    ...
# 409            US                 Oregon   5373
# 227         Italy                Tuscany   5897
# 118        France               Bordeaux   5941
# 415            US             Washington   8639
# 392            US             California  36250
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#           country         province    len
# 392            US       California  36250
# 415            US       Washington   8639
# 118        France         Bordeaux   5941
# 227         Italy          Tuscany   5897
# 409            US           Oregon   5373
# ..            ...              ...    ...
# 101       Croatia              Krk      1
# 247   New Zealand        Gladstone      1
# 357  South Africa  Piekenierskloof      1
# 63          Chile          Coelemu      1
# 149        Greece           Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# 6    Australia          Tasmania    42
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
reviews.head(3)
# Out:
#     country  ...               winery
# 0     Italy  ...              Nicosia
# 1  Portugal  ...  Quinta dos Avidagos
# 2        US  ...            Rainstorm
#
# [3 rows x 13 columns]

# %%
reviews['province'].value_counts().head(10).plot.bar()

# %%
(reviews['province'].value_counts().head(10) / len(reviews)).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.line()

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %%
reviews[reviews['price'] < 200]['price'].plot.hist()

# %%
reviews['price'].plot.hist()

# %%
reviews[reviews['price'] > 1500]
# Out:
#        country  ...                         winery
# 1559    France  ...                Château Margaux
# 15841   France  ...                 Château Pétrus
# 65355   France  ...                 Château Pétrus
# 80293   France  ...       Château les Ormes Sorbet
# 98384   France  ...  Domaine du Comte Liger-Belair
# 113568  France  ...  Domaine du Comte Liger-Belair
# 120397      US  ...                          Blair
#
# [7 rows x 13 columns]

# %%
reviews['points'].plot.hist()

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
#           ...
# 129975    90.0
# 129976    90.0
# 129977    90.0
# 129978    90.0
# 129979    90.0
# Name: points, Length: 129980, dtype: float64

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %%
reviews[pd.isna(reviews)]
# Out:
#        country description designation  points  price province region_1  \
# 0          NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 1          NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 2          NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 3          NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 4          NaN         NaN         NaN     NaN    NaN      NaN      NaN
# ...        ...         ...         ...     ...    ...      ...      ...
# 129975     NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 129976     NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 129977     NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 129978     NaN         NaN         NaN     NaN    NaN      NaN      NaN
# 129979     NaN         NaN         NaN     NaN    NaN      NaN      NaN
#
#        region_2 taster_name taster_twitter_handle title variety winery
# ...

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 914        NaN  Amber in color, this wine has aromas of peach ...
# 3132       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4244       NaN  Violet-red in color, this semisweet wine has a...
# 9510       NaN  This mouthwatering blend starts with a nose of...
# 9751       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124182     NaN  This Swiss red blend is composed of four varie...
# 129416     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129417     NaN  El Capricho is one of Uruguay's more consisten...
# 129599     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129909     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 914                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129975              Unknown
# 129976         Oregon Other
# 129977              Unknown
# 129978              Unknown
# 129979              Unknown
# Name: region_2, Length: 129980, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129975            NaN
# 129976    @paulgwine
# 129977     @vossroger
# 129978     @vossroger
# 129979     @vossroger
# Name: taster_twitter_handle, Length: 129980, dtype: object

# %%
drop_na_reviews = reviews.dropna(axis=0)
drop_na_reviews
# Out:
#        country                                        description  \
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 24          US  This wine from the Geneseo district offers aro...
# 26          US  Oak and earth intermingle around robust aromas...
# 36          US  As with many of the Erath 2010 vineyard design...
# ...        ...                                                ...
# 129928      US  This ripe, rich, almost decadently thick wine ...
# 129935      US  This pure Syrah from Reininger's estate vineya...
# 129954      US  Hailing from one of the more popular vineyards...
# 129958      US  There's no bones about the use of oak in this ...
# 129959      US  This opens with herbaceous dollops of thyme an...
#
#                                designation  points  price    province  \
# 4       Vintner's Reserve Wild Child Block      87   65.0      Oregon
# ...

# %%
drop_na_reviews = drop_na_reviews.reset_index()
drop_na_reviews
# Out:
#         index country                                        description  \
# 0           4      US  Much like the regular bottling from 2012, this...
# 1          10      US  Soft, supple plum envelopes an oaky structure ...
# 2          24      US  This wine from the Geneseo district offers aro...
# 3          26      US  Oak and earth intermingle around robust aromas...
# 4          36      US  As with many of the Erath 2010 vineyard design...
# ...       ...     ...                                                ...
# 22382  129928      US  This ripe, rich, almost decadently thick wine ...
# 22383  129935      US  This pure Syrah from Reininger's estate vineya...
# 22384  129954      US  Hailing from one of the more popular vineyards...
# 22385  129958      US  There's no bones about the use of oak in this ...
# 22386  129959      US  This opens with herbaceous dollops of thyme an...
#
#                               designation  points  price    province  \
# ...

# %%
drop_na_reviews.shape
# Out:
# (22387, 14)
